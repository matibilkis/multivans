# %% [markdown]
# In this notebook we give a proof of concept of unitary compiling using TFQ.

# %%
# %load_ext autoreload
# %autoreload 2

import sympy 
import numpy as np 
import pandas as pd 
import tensorflow as tf
from utilities.circuit_database import CirqTranslater
from utilities.templates import *
from utilities.variational import Minimizer
import matplotlib.pyplot as plt 
import tensorflow_quantum as tfq
import cirq
from utilities.compiling import *
from utilities.misc import *
from utilities.simplifier import Simplifier
from utilities.discrimination import *
from utilities.idinserter import IdInserter
from utilities.evaluator import Evaluator
from utilities.gate_killer import GateKiller
from ast import literal_eval

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)

q = 0
other_qs = list(range(translator.n_qubits))
other_qs.remove(q)
indds = [translator.cnots_index[str([q,k])] for k in other_qs]
cdb = pd.DataFrame([gate_template(i) for i in indds])

circuit_db = concatenate_dbs([z_layer_db(translator), cdb])

for q in range(1, translator.n_qubits):
    other_qs = list(range(translator.n_qubits))
    other_qs.remove(q)
    indds = [translator.cnots_index[str([q,k])] for k in other_qs]
    cdb = pd.DataFrame([gate_template(i) for i in indds])
    circuit_db = concatenate_dbs([circuit_db ,cdb])

c, circuit_db = translator.give_circuit(circuit_db)
db1 = concatenate_dbs([x_layer_db(translator)]*3)

circuit_db = concatenate_dbs([circuit_db, db1])
c, circuit_db = translator.give_circuit(circuit_db)

cdb = []
for ind, qubits in list(translator.indexed_cnots.items()):
    cdb.append(gate_template(int(ind), block_id=0))
    con, tar = qubits
    cdb.append(gate_template(int(con + translator.number_of_cnots), param_value = np.random.random()))
    cdb.append(gate_template(int(tar + translator.number_of_cnots + translator.n_qubits), param_value = np.random.random()))
c6_db = pd.DataFrame(cdb)
circuit_db = concatenate_dbs([circuit_db, c6_db])

c, circuit_db = translator.give_circuit(circuit_db)

dd1  =circuit_db.copy()
dd1["block_id"] = 1
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 2
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 3
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)


simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt76
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt77
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt78
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt79
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt80
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt81
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt82
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt83
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt84
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt85
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt86
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt87
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt88
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt89
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt90
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt91
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt92
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt93
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt94
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt95
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt96
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt97
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt98
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt99
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt100
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt101
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt102
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt103
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt104
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt105
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt106
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt107
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt108
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt109
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt110
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt111
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt112
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt113
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt114
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt115
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fda941beda0>>
# hey, i'm still simplifying, cnt116
# hey, i'm still simplifying, cnt117

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 8.494124471751448e-16
#                                           ┌──┐                                                                                                                                                     ┌──┐                                                                                                                                           ┌──┐                                                                                                                                                       ┌──┐                                                                                                                                           ┌──┐                                                                                                                                                          ┌──┐                                                                                                                                                    ┌──┐                                                                                                                                                                 ┌──┐                                                                                                                                                    ┌──┐                                                                                                                                                                 ┌──┐                                                                                                                                                    ┌──┐                                                                                                                                                                 ┌──┐                                                                                                                                                    ┌──┐                                                                                                                                                                 ┌──┐                                                                                                                                                    ┌──┐                                                                                                                                                                 ┌──┐
# (0, 0): ───Rz(th_0)───@───@───@───X─────────X────────────X───Rx(th_4)───Rx(th_8)───Rx(th_12)───────────────@───────────Rz(th_16)───@───Rz(th_18)───@───Rz(th_20)───X───Rx(th_23)─────────────────────X────Rx(th_29)───────────────────────────────────X───Rx(th_35)───Rz(th_40)───────────────────────────@───────────────────────@───@───X─────────X────────────X───Rx(th_44)───Rx(th_48)───Rx(th_52)───────────────@───────────Rz(th_56)───@───Rz(th_58)───@───Rz(th_60)───X───Rx(th_63)─────────────────────X────Rx(th_69)───────────────────────────────────X───Rx(th_75)───Rz(th_80)───────────────────────────@───────────────────────@───@───X─────────X────────────X───Rx(th_84)───Rx(th_88)───Rx(th_92)───────────────@───────────Rz(th_96)───@───Rz(th_98)───@───Rz(th_100)───X───Rx(th_103)──────────────────────X────Rx(th_109)─────────────────────────────────────X───Rx(th_115)───Rz(th_120)─────────────────────────────@─────────────────────────@───@───X─────────X────────────X───Rx(th_124)───Rx(th_128)───Rx(th_132)────────────────@────────────Rz(th_136)───@───Rz(th_138)───@───Rz(th_140)───X───Rx(th_143)──────────────────────X────Rx(th_149)─────────────────────────────────────X───Rx(th_155)───Rz(th_160)─────────────────────────────@─────────────────────────@───@───X─────────X────────────X───Rx(th_164)───Rx(th_168)───Rx(th_172)────────────────@────────────Rz(th_176)───@───Rz(th_178)───@───Rz(th_180)───X───Rx(th_183)──────────────────────X────Rx(th_189)─────────────────────────────────────X───Rx(th_195)───Rz(th_200)─────────────────────────────@─────────────────────────@───@───X─────────X────────────X───Rx(th_204)───Rx(th_208)───Rx(th_212)────────────────@────────────Rz(th_216)───@───Rz(th_218)───@───Rz(th_220)───X───Rx(th_223)──────────────────────X────Rx(th_229)─────────────────────────────────────X───Rx(th_235)───Rz(th_240)─────────────────────────────@─────────────────────────@───@───X─────────X────────────X───Rx(th_244)───Rx(th_248)───Rx(th_252)────────────────@────────────Rz(th_256)───@───Rz(th_258)───@───Rz(th_260)───X───Rx(th_263)──────────────────────X────Rx(th_269)─────────────────────────────────────X───Rx(th_275)───Rz(th_280)─────────────────────────────@─────────────────────────@───@───X─────────X────────────X───Rx(th_284)───Rx(th_288)───Rx(th_292)────────────────@────────────Rz(th_296)───@───Rz(th_298)───@───Rz(th_300)───X───Rx(th_303)──────────────────────X────Rx(th_309)─────────────────────────────────────X───Rx(th_315)─────────────────────────────────────
#                       │   │   │   │         │            │                                                 │                       │               │               │                                 │                                                │                                                   │                       │   │   │         │            │                                                   │                       │               │               │                                 │                                                │                                                   │                       │   │   │         │            │                                                   │                       │               │                │                                   │                                                   │                                                       │                         │   │   │         │            │                                                       │                         │                │                │                                   │                                                   │                                                       │                         │   │   │         │            │                                                       │                         │                │                │                                   │                                                   │                                                       │                         │   │   │         │            │                                                       │                         │                │                │                                   │                                                   │                                                       │                         │   │   │         │            │                                                       │                         │                │                │                                   │                                                   │                                                       │                         │   │   │         │            │                                                       │                         │                │                │                                   │                                                   │
# (0, 1): ───Rz(th_1)───X───┼───┼───@───@────@┼────X───────┼───X──────────Rx(th_5)───Rx(th_9)────Rx(th_13)───X───────────Rx(th_17)───┼───────────────┼───────────────@───Rz(th_22)───@───Rz(th_24)────@┼────Rz(th_26)───X───Rx(th_31)───────────────────┼───────────────X───────────Rx(th_37)───Rz(th_41)───X───────────────────────┼───┼───@───@────@┼────X───────┼───X───────────Rx(th_45)───Rx(th_49)───Rx(th_53)───X───────────Rx(th_57)───┼───────────────┼───────────────@───Rz(th_62)───@───Rz(th_64)────@┼────Rz(th_66)───X───Rx(th_71)───────────────────┼───────────────X───────────Rx(th_77)───Rz(th_81)───X───────────────────────┼───┼───@───@────@┼────X───────┼───X───────────Rx(th_85)───Rx(th_89)───Rx(th_93)───X───────────Rx(th_97)───┼───────────────┼────────────────@───Rz(th_102)───@───Rz(th_104)────@┼────Rz(th_106)───X───Rx(th_111)────────────────────┼────────────────X────────────Rx(th_117)───Rz(th_121)───X─────────────────────────┼───┼───@───@────@┼────X───────┼───X────────────Rx(th_125)───Rx(th_129)───Rx(th_133)───X────────────Rx(th_137)───┼────────────────┼────────────────@───Rz(th_142)───@───Rz(th_144)────@┼────Rz(th_146)───X───Rx(th_151)────────────────────┼────────────────X────────────Rx(th_157)───Rz(th_161)───X─────────────────────────┼───┼───@───@────@┼────X───────┼───X────────────Rx(th_165)───Rx(th_169)───Rx(th_173)───X────────────Rx(th_177)───┼────────────────┼────────────────@───Rz(th_182)───@───Rz(th_184)────@┼────Rz(th_186)───X───Rx(th_191)────────────────────┼────────────────X────────────Rx(th_197)───Rz(th_201)───X─────────────────────────┼───┼───@───@────@┼────X───────┼───X────────────Rx(th_205)───Rx(th_209)───Rx(th_213)───X────────────Rx(th_217)───┼────────────────┼────────────────@───Rz(th_222)───@───Rz(th_224)────@┼────Rz(th_226)───X───Rx(th_231)────────────────────┼────────────────X────────────Rx(th_237)───Rz(th_241)───X─────────────────────────┼───┼───@───@────@┼────X───────┼───X────────────Rx(th_245)───Rx(th_249)───Rx(th_253)───X────────────Rx(th_257)───┼────────────────┼────────────────@───Rz(th_262)───@───Rz(th_264)────@┼────Rz(th_266)───X───Rx(th_271)────────────────────┼────────────────X────────────Rx(th_277)───Rz(th_281)───X─────────────────────────┼───┼───@───@────@┼────X───────┼───X────────────Rx(th_285)───Rx(th_289)───Rx(th_293)───X────────────Rx(th_297)───┼────────────────┼────────────────@───Rz(th_302)───@───Rz(th_304)────@┼────Rz(th_306)───X───Rx(th_311)────────────────────┼────────────────X───Rx(th_317)────────────────────
#                           │   │       │    ││    │       │   │                                                                     │               │                               │                ││                │                               │               │                                                           │   │       │    ││    │       │   │                                                                       │               │                               │                ││                │                               │               │                                                           │   │       │    ││    │       │   │                                                                       │               │                                 │                 ││                 │                                 │                │                                                                │   │       │    ││    │       │   │                                                                             │                │                                 │                 ││                 │                                 │                │                                                                │   │       │    ││    │       │   │                                                                             │                │                                 │                 ││                 │                                 │                │                                                                │   │       │    ││    │       │   │                                                                             │                │                                 │                 ││                 │                                 │                │                                                                │   │       │    ││    │       │   │                                                                             │                │                                 │                 ││                 │                                 │                │                                                                │   │       │    ││    │       │   │                                                                             │                │                                 │                 ││                 │                                 │                │
# (0, 2): ───Rz(th_2)───────X───┼───────X────┼@────@───@───┼───┼──────────X──────────Rx(th_6)────Rx(th_10)───Rx(th_14)───────────────X───Rx(th_19)───┼───────────────────────────────X───Rx(th_25)────┼@────Rz(th_28)───@───Rz(th_30)───@───Rz(th_32)───┼───────────────┼───────────────────────X───────────Rx(th_39)───Rz(th_42)───X───┼───────X────┼@────@───@───┼───┼───────────X───────────Rx(th_46)───Rx(th_50)───Rx(th_54)───────────────X───Rx(th_59)───┼───────────────────────────────X───Rx(th_65)────┼@────Rz(th_68)───@───Rz(th_70)───@───Rz(th_72)───┼───────────────┼───────────────────────X───────────Rx(th_79)───Rz(th_82)───X───┼───────X────┼@────@───@───┼───┼───────────X───────────Rx(th_86)───Rx(th_90)───Rx(th_94)───────────────X───Rx(th_99)───┼─────────────────────────────────X───Rx(th_105)────┼@────Rz(th_108)───@───Rz(th_110)───@───Rz(th_112)───┼────────────────┼─────────────────────────X────────────Rx(th_119)───Rz(th_122)───X───┼───────X────┼@────@───@───┼───┼────────────X────────────Rx(th_126)───Rx(th_130)───Rx(th_134)────────────────X───Rx(th_139)───┼─────────────────────────────────X───Rx(th_145)────┼@────Rz(th_148)───@───Rz(th_150)───@───Rz(th_152)───┼────────────────┼─────────────────────────X────────────Rx(th_159)───Rz(th_162)───X───┼───────X────┼@────@───@───┼───┼────────────X────────────Rx(th_166)───Rx(th_170)───Rx(th_174)────────────────X───Rx(th_179)───┼─────────────────────────────────X───Rx(th_185)────┼@────Rz(th_188)───@───Rz(th_190)───@───Rz(th_192)───┼────────────────┼─────────────────────────X────────────Rx(th_199)───Rz(th_202)───X───┼───────X────┼@────@───@───┼───┼────────────X────────────Rx(th_206)───Rx(th_210)───Rx(th_214)────────────────X───Rx(th_219)───┼─────────────────────────────────X───Rx(th_225)────┼@────Rz(th_228)───@───Rz(th_230)───@───Rz(th_232)───┼────────────────┼─────────────────────────X────────────Rx(th_239)───Rz(th_242)───X───┼───────X────┼@────@───@───┼───┼────────────X────────────Rx(th_246)───Rx(th_250)───Rx(th_254)────────────────X───Rx(th_259)───┼─────────────────────────────────X───Rx(th_265)────┼@────Rz(th_268)───@───Rz(th_270)───@───Rz(th_272)───┼────────────────┼─────────────────────────X────────────Rx(th_279)───Rz(th_282)───X───┼───────X────┼@────@───@───┼───┼────────────X────────────Rx(th_286)───Rx(th_290)───Rx(th_294)────────────────X───Rx(th_299)───┼─────────────────────────────────X───Rx(th_305)────┼@────Rz(th_308)───@───Rz(th_310)───@───Rz(th_312)───┼────────────────┼────────────────X───Rx(th_319)───
#                               │            │         │   │   │          │                                                                          │                                                │                                 │               │               │                       │                                       │            │         │   │   │           │                                                                           │                                                │                                 │               │               │                       │                                       │            │         │   │   │           │                                                                           │                                                   │                                   │                │                │                         │                                          │            │         │   │   │            │                                                                                 │                                                   │                                   │                │                │                         │                                          │            │         │   │   │            │                                                                                 │                                                   │                                   │                │                │                         │                                          │            │         │   │   │            │                                                                                 │                                                   │                                   │                │                │                         │                                          │            │         │   │   │            │                                                                                 │                                                   │                                   │                │                │                         │                                          │            │         │   │   │            │                                                                                 │                                                   │                                   │                │                │                │
# (0, 3): ───Rz(th_3)───────────X────────────X─────────X───@───@──────────@──────────Rx(th_7)────Rx(th_11)───Rx(th_15)───────────────────────────────X───Rx(th_21)────────────────────────────────────X─────Rx(th_27)───────────────────X───Rx(th_33)───@───Rz(th_34)───@───────────Rz(th_36)───@───────────Rz(th_38)───Rz(th_43)───────X────────────X─────────X───@───@───────────@───────────Rx(th_47)───Rx(th_51)───Rx(th_55)───────────────────────────────X───Rx(th_61)────────────────────────────────────X─────Rx(th_67)───────────────────X───Rx(th_73)───@───Rz(th_74)───@───────────Rz(th_76)───@───────────Rz(th_78)───Rz(th_83)───────X────────────X─────────X───@───@───────────@───────────Rx(th_87)───Rx(th_91)───Rx(th_95)───────────────────────────────X───Rx(th_101)──────────────────────────────────────X─────Rx(th_107)────────────────────X───Rx(th_113)───@───Rz(th_114)───@────────────Rz(th_116)───@────────────Rz(th_118)───Rz(th_123)───────X────────────X─────────X───@───@────────────@────────────Rx(th_127)───Rx(th_131)───Rx(th_135)─────────────────────────────────X───Rx(th_141)──────────────────────────────────────X─────Rx(th_147)────────────────────X───Rx(th_153)───@───Rz(th_154)───@────────────Rz(th_156)───@────────────Rz(th_158)───Rz(th_163)───────X────────────X─────────X───@───@────────────@────────────Rx(th_167)───Rx(th_171)───Rx(th_175)─────────────────────────────────X───Rx(th_181)──────────────────────────────────────X─────Rx(th_187)────────────────────X───Rx(th_193)───@───Rz(th_194)───@────────────Rz(th_196)───@────────────Rz(th_198)───Rz(th_203)───────X────────────X─────────X───@───@────────────@────────────Rx(th_207)───Rx(th_211)───Rx(th_215)─────────────────────────────────X───Rx(th_221)──────────────────────────────────────X─────Rx(th_227)────────────────────X───Rx(th_233)───@───Rz(th_234)───@────────────Rz(th_236)───@────────────Rz(th_238)───Rz(th_243)───────X────────────X─────────X───@───@────────────@────────────Rx(th_247)───Rx(th_251)───Rx(th_255)─────────────────────────────────X───Rx(th_261)──────────────────────────────────────X─────Rx(th_267)────────────────────X───Rx(th_273)───@───Rz(th_274)───@────────────Rz(th_276)───@────────────Rz(th_278)───Rz(th_283)───────X────────────X─────────X───@───@────────────@────────────Rx(th_287)───Rx(th_291)───Rx(th_295)─────────────────────────────────X───Rx(th_301)──────────────────────────────────────X─────Rx(th_307)────────────────────X───Rx(th_313)───@───Rz(th_314)───@───Rz(th_316)───@───Rz(th_318)───
#                                           └──┘                                                                                                                                                     └──┘                                                                                                                                           └──┘                                                                                                                                                       └──┘                                                                                                                                           └──┘                                                                                                                                                          └──┘                                                                                                                                                    └──┘                                                                                                                                                                 └──┘                                                                                                                                                    └──┘                                                                                                                                                                 └──┘                                                                                                                                                    └──┘                                                                                                                                                                 └──┘                                                                                                                                                    └──┘                                                                                                                                                                 └──┘                                                                                                                                                    └──┘                                                                                                                                                                 └──┘
#                               ┌──┐                              ┌─────────┐   ┌─────────┐                                            ┌──────────┐                           ┌──────────┐                                                                                                                                                               ┌──┐                               ┌──────────┐   ┌──────────┐                                               ┌──────────┐                           ┌──────────┐                                                                                                                                                               ┌──┐                               ┌──────────┐   ┌──────────┐                                               ┌──────────┐                           ┌──────────┐                                                                                                                                                       ┌──┐                               ┌───────────┐   ┌───────────┐                                                  ┌───────────┐                             ┌───────────┐                                                                                                                                                                          ┌──┐                                ┌───────────┐   ┌───────────┐                                                  ┌───────────┐                             ┌───────────┐                                                                                                                                                                 ┌──┐                                ┌───────────┐   ┌───────────┐                                                  ┌───────────┐                             ┌───────────┐                                                                                                                                                                 ┌──┐                                ┌───────────┐   ┌───────────┐                                                  ┌───────────┐                             ┌───────────┐                                                                                                                                                                 ┌──┐                                ┌───────────┐   ┌───────────┐                                                  ┌───────────┐                             ┌───────────┐
# (0, 0): ───Rz(th_3)───X─────────X────────────X───Rx(th_4)───@────────────@─────────────@────Rz(th_7)───Rz(th_8)───Rz(th_9)───X────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────X───Rx(th_23)───Rx(th_24)───Rx(th_25)───────────────@───────────@───────────@───Rz(th_35)───X─────────X────────────X───Rx(th_36)───@─────────────@──────────────@────Rz(th_39)───Rz(th_40)───Rz(th_41)───X────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────X───Rx(th_55)───Rx(th_56)───Rx(th_57)───────────────@───────────@───────────@───Rz(th_67)───X─────────X────────────X───Rx(th_68)───@─────────────@──────────────@────Rz(th_71)───Rz(th_72)───Rz(th_73)───X────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────X───Rx(th_87)───Rx(th_88)───Rx(th_89)───────────────@───────────@───@───Rz(th_98)───X─────────X────────────X───Rx(th_99)───@──────────────@───────────────@────Rz(th_102)───Rz(th_103)───Rz(th_104)───X────────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────────X───Rx(th_118)───Rx(th_119)───Rx(th_120)────────────────@────────────@────────────@───Rz(th_130)───X─────────X────────────X───Rx(th_131)───@──────────────@───────────────@────Rz(th_134)───Rz(th_135)───Rz(th_136)───X────────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────────X───Rx(th_150)───Rx(th_151)───Rx(th_152)────────────────@────────────@───@───Rz(th_161)───X─────────X────────────X───Rx(th_162)───@──────────────@───────────────@────Rz(th_165)───Rz(th_166)───Rz(th_167)───X────────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────────X───Rx(th_181)───Rx(th_182)───Rx(th_183)────────────────@────────────@───@───Rz(th_192)───X─────────X────────────X───Rx(th_193)───@──────────────@───────────────@────Rz(th_196)───Rz(th_197)───Rz(th_198)───X────────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────────X───Rx(th_212)───Rx(th_213)───Rx(th_214)────────────────@────────────@───@───Rz(th_223)───X─────────X────────────X───Rx(th_224)───@──────────────@───────────────@────Rz(th_227)───Rz(th_228)───Rz(th_229)───X────────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────────X───Rx(th_243)───Rx(th_244)───Rx(th_245)─────────────────────────────
#                       │         │            │              │            │             │                                     │                                                        │                                                            │                                                   │           │           │               │         │            │               │             │              │                                        │                                                        │                                                            │                                                   │           │           │               │         │            │               │             │              │                                        │                                                        │                                                            │                                                   │           │   │               │         │            │               │              │               │                                           │                                                            │                                                                │                                                       │            │            │                │         │            │                │              │               │                                           │                                                            │                                                                │                                                       │            │   │                │         │            │                │              │               │                                           │                                                            │                                                                │                                                       │            │   │                │         │            │                │              │               │                                           │                                                            │                                                                │                                                       │            │   │                │         │            │                │              │               │                                           │                                                            │                                                                │
# (0, 1): ───Rz(th_0)───@───@────@┼────X───────┼───X──────────X────Rx(th_5)┼─────Rx(th_6)┼─────────────────────────────────────@───@─────────────@────Rz(th_13)───Rz(th_14)────Rz(th_15)┼────X───────────────────────────────────────────────────────┼───X───────────Rx(th_26)───Rx(th_27)───Rz(th_32)───X───────────┼───────────┼───────────────@───@────@┼────X───────┼───X───────────X────Rx(th_37)┼─────Rx(th_38)┼────────────────────────────────────────@───@─────────────@────Rz(th_45)───Rz(th_46)────Rz(th_47)┼────X───────────────────────────────────────────────────────┼───X───────────Rx(th_58)───Rx(th_59)───Rz(th_64)───X───────────┼───────────┼───────────────@───@────@┼────X───────┼───X───────────X────Rx(th_69)┼─────Rx(th_70)┼────────────────────────────────────────@───@─────────────@────Rz(th_77)───Rz(th_78)────Rz(th_79)┼────X───────────────────────────────────────────────────────┼───X───────────Rx(th_90)───Rx(th_91)───Rz(th_95)───X───────────┼───┼───────────────@───@────@┼────X───────┼───X───────────X────Rx(th_100)┼─────Rx(th_101)┼───────────────────────────────────────────@───@──────────────@────Rz(th_108)───Rz(th_109)────Rz(th_110)┼────X───────────────────────────────────────────────────────────┼───X────────────Rx(th_121)───Rx(th_122)───Rz(th_127)───X────────────┼────────────┼────────────────@───@────@┼────X───────┼───X────────────X────Rx(th_132)┼─────Rx(th_133)┼───────────────────────────────────────────@───@──────────────@────Rz(th_140)───Rz(th_141)────Rz(th_142)┼────X───────────────────────────────────────────────────────────┼───X────────────Rx(th_153)───Rx(th_154)───Rz(th_158)───X────────────┼───┼────────────────@───@────@┼────X───────┼───X────────────X────Rx(th_163)┼─────Rx(th_164)┼───────────────────────────────────────────@───@──────────────@────Rz(th_171)───Rz(th_172)────Rz(th_173)┼────X───────────────────────────────────────────────────────────┼───X────────────Rx(th_184)───Rx(th_185)───Rz(th_189)───X────────────┼───┼────────────────@───@────@┼────X───────┼───X────────────X────Rx(th_194)┼─────Rx(th_195)┼───────────────────────────────────────────@───@──────────────@────Rz(th_202)───Rz(th_203)────Rz(th_204)┼────X───────────────────────────────────────────────────────────┼───X────────────Rx(th_215)───Rx(th_216)───Rz(th_220)───X────────────┼───┼────────────────@───@────@┼────X───────┼───X────────────X────Rx(th_225)┼─────Rx(th_226)┼───────────────────────────────────────────@───@──────────────@────Rz(th_233)───Rz(th_234)────Rz(th_235)┼────X───────────────────────────────────────────────────────────┼───X────────────Rx(th_246)───Rx(th_247)─────────────────────────────
#                           │    ││    │       │   │                       │             │                                         │             │                                      │    │                                                       │   │                                                           │           │                   │    ││    │       │   │                         │              │                                            │             │                                      │    │                                                       │   │                                                           │           │                   │    ││    │       │   │                         │              │                                            │             │                                      │    │                                                       │   │                                                           │   │                   │    ││    │       │   │                          │               │                                               │              │                                         │    │                                                           │   │                                                                │            │                    │    ││    │       │   │                           │               │                                               │              │                                         │    │                                                           │   │                                                                │   │                    │    ││    │       │   │                           │               │                                               │              │                                         │    │                                                           │   │                                                                │   │                    │    ││    │       │   │                           │               │                                               │              │                                         │    │                                                           │   │                                                                │   │                    │    ││    │       │   │                           │               │                                               │              │                                         │    │                                                           │   │
# (0, 2): ───Rz(th_1)───────X────┼@────@───@───┼───┼──────────X────────────X─────────────┼─────────────────────────────────────────X────Rx(th_10)┼────Rx(th_11)───Rx(th_12)─────────────@────@───@───Rz(th_19)───Rz(th_20)───Rz(th_21)───────────────┼───┼───────────X───────────Rx(th_31)───Rz(th_33)───────────────X───────────┼───────────────────X────┼@────@───@───┼───┼───────────X─────────────X──────────────┼────────────────────────────────────────────X────Rx(th_42)┼────Rx(th_43)───Rx(th_44)─────────────@────@───@───Rz(th_51)───Rz(th_52)───Rz(th_53)───────────────┼───┼───────────X───────────Rx(th_63)───Rz(th_65)───────────────X───────────┼───────────────────X────┼@────@───@───┼───┼───────────X─────────────X──────────────┼────────────────────────────────────────────X────Rx(th_74)┼────Rx(th_75)───Rx(th_76)─────────────@────@───@───Rz(th_83)───Rz(th_84)───Rz(th_85)───────────────┼───┼───────────X───────────Rx(th_94)───Rz(th_96)───────────────X───┼───────────────────X────┼@────@───@───┼───┼───────────X──────────────X───────────────┼───────────────────────────────────────────────X────Rx(th_105)┼────Rx(th_106)───Rx(th_107)──────────────@────@───@───Rz(th_114)───Rz(th_115)───Rz(th_116)────────────────┼───┼────────────X────────────Rx(th_126)───Rz(th_128)────────────────X────────────┼────────────────────X────┼@────@───@───┼───┼────────────X──────────────X───────────────┼───────────────────────────────────────────────X────Rx(th_137)┼────Rx(th_138)───Rx(th_139)──────────────@────@───@───Rz(th_146)───Rz(th_147)───Rz(th_148)────────────────┼───┼────────────X────────────Rx(th_157)───Rz(th_159)────────────────X───┼────────────────────X────┼@────@───@───┼───┼────────────X──────────────X───────────────┼───────────────────────────────────────────────X────Rx(th_168)┼────Rx(th_169)───Rx(th_170)──────────────@────@───@───Rz(th_177)───Rz(th_178)───Rz(th_179)────────────────┼───┼────────────X────────────Rx(th_188)───Rz(th_190)────────────────X───┼────────────────────X────┼@────@───@───┼───┼────────────X──────────────X───────────────┼───────────────────────────────────────────────X────Rx(th_199)┼────Rx(th_200)───Rx(th_201)──────────────@────@───@───Rz(th_208)───Rz(th_209)───Rz(th_210)────────────────┼───┼────────────X────────────Rx(th_219)───Rz(th_221)────────────────X───┼────────────────────X────┼@────@───@───┼───┼────────────X──────────────X───────────────┼───────────────────────────────────────────────X────Rx(th_230)┼────Rx(th_231)───Rx(th_232)──────────────@────@───@───Rz(th_239)───Rz(th_240)───Rz(th_241)────────────────┼───┼────────────X────────────Rx(th_251)─────────────────────────────
#                                │         │   │   │          │                          │                                                       │                                               │                                                   │   │           │                                                           │                        │         │   │   │           │                            │                                                          │                                               │                                                   │   │           │                                                           │                        │         │   │   │           │                            │                                                          │                                               │                                                   │   │           │                                                   │                        │         │   │   │           │                              │                                                              │                                                  │                                                       │   │            │                                                                │                         │         │   │   │            │                              │                                                              │                                                  │                                                       │   │            │                                                       │                         │         │   │   │            │                              │                                                              │                                                  │                                                       │   │            │                                                       │                         │         │   │   │            │                              │                                                              │                                                  │                                                       │   │            │                                                       │                         │         │   │   │            │                              │                                                              │                                                  │                                                       │   │            │
# (0, 3): ───Rz(th_2)────────────X─────────X───@───@──────────@──────────────────────────X───────────────────────────────────────────────────────X───────────────────────────────────────────────X───Rx(th_16)───Rx(th_17)───Rx(th_18)───Rx(th_22)───@───@───────────@───────────Rz(th_28)───Rz(th_29)───Rz(th_30)───Rz(th_34)───X────────────────────────X─────────X───@───@───────────@────────────────────────────X──────────────────────────────────────────────────────────X───────────────────────────────────────────────X───Rx(th_48)───Rx(th_49)───Rx(th_50)───Rx(th_54)───@───@───────────@───────────Rz(th_60)───Rz(th_61)───Rz(th_62)───Rz(th_66)───X────────────────────────X─────────X───@───@───────────@────────────────────────────X──────────────────────────────────────────────────────────X───────────────────────────────────────────────X───Rx(th_80)───Rx(th_81)───Rx(th_82)───Rx(th_86)───@───@───────────@───────────Rz(th_92)───Rz(th_93)───Rz(th_97)───────X────────────────────────X─────────X───@───@───────────@──────────────────────────────X──────────────────────────────────────────────────────────────X──────────────────────────────────────────────────X───Rx(th_111)───Rx(th_112)───Rx(th_113)───Rx(th_117)───@───@────────────@────────────Rz(th_123)───Rz(th_124)───Rz(th_125)───Rz(th_129)───X─────────────────────────X─────────X───@───@────────────@──────────────────────────────X──────────────────────────────────────────────────────────────X──────────────────────────────────────────────────X───Rx(th_143)───Rx(th_144)───Rx(th_145)───Rx(th_149)───@───@────────────@────────────Rz(th_155)───Rz(th_156)───Rz(th_160)───────X─────────────────────────X─────────X───@───@────────────@──────────────────────────────X──────────────────────────────────────────────────────────────X──────────────────────────────────────────────────X───Rx(th_174)───Rx(th_175)───Rx(th_176)───Rx(th_180)───@───@────────────@────────────Rz(th_186)───Rz(th_187)───Rz(th_191)───────X─────────────────────────X─────────X───@───@────────────@──────────────────────────────X──────────────────────────────────────────────────────────────X──────────────────────────────────────────────────X───Rx(th_205)───Rx(th_206)───Rx(th_207)───Rx(th_211)───@───@────────────@────────────Rz(th_217)───Rz(th_218)───Rz(th_222)───────X─────────────────────────X─────────X───@───@────────────@──────────────────────────────X──────────────────────────────────────────────────────────────X──────────────────────────────────────────────────X───Rx(th_236)───Rx(th_237)───Rx(th_238)───Rx(th_242)───@───@────────────@────────────Rz(th_248)───Rz(th_249)───Rz(th_250)───
#                               └──┘                              └─────────┘   └─────────┘                                            └──────────┘                           └──────────┘                                                                                                                                                               └──┘                               └──────────┘   └──────────┘                                               └──────────┘                           └──────────┘                                                                                                                                                               └──┘                               └──────────┘   └──────────┘                                               └──────────┘                           └──────────┘                                                                                                                                                       └──┘                               └───────────┘   └───────────┘                                                  └───────────┘                             └───────────┘                                                                                                                                                                          └──┘                                └───────────┘   └───────────┘                                                  └───────────┘                             └───────────┘                                                                                                                                                                 └──┘                                └───────────┘   └───────────┘                                                  └───────────┘                             └───────────┘                                                                                                                                                                 └──┘                                └───────────┘   └───────────┘                                                  └───────────┘                             └───────────┘                                                                                                                                                                 └──┘                                └───────────┘   └───────────┘                                                  └───────────┘                             └───────────┘

# %%
len(simplified_db)
# Out:
# 441

# %%
len(circuit_db)
# Out:
# 512
