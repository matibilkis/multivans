# %% [markdown]
# In this notebook we give a proof of concept of unitary compiling using TFQ.

# %%
# %load_ext autoreload
# %autoreload 2

import sympy 
import numpy as np 
import pandas as pd 
import tensorflow as tf
from utilities.circuit_database import CirqTranslater
from utilities.templates import *
from utilities.variational import Minimizer
import matplotlib.pyplot as plt 
import tensorflow_quantum as tfq
import cirq
from utilities.compiling import *
from utilities.misc import *
from utilities.simplifier import Simplifier
from utilities.discrimination import *
from utilities.idinserter import IdInserter
from utilities.evaluator import Evaluator
from utilities.gate_killer import GateKiller
from ast import literal_eval
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)

q = 0
other_qs = list(range(translator.n_qubits))
other_qs.remove(q)
indds = [translator.cnots_index[str([q,k])] for k in other_qs]
cdb = pd.DataFrame([gate_template(i) for i in indds])

circuit_db = concatenate_dbs([z_layer_db(translator), cdb])

for q in range(1, translator.n_qubits):
    other_qs = list(range(translator.n_qubits))
    other_qs.remove(q)
    indds = [translator.cnots_index[str([q,k])] for k in other_qs]
    cdb = pd.DataFrame([gate_template(i) for i in indds])
    circuit_db = concatenate_dbs([circuit_db ,cdb])

c, circuit_db = translator.give_circuit(circuit_db)

db1 = concatenate_dbs([x_layer_db(translator)]*3)
#db2 = concatenate_dbs([z_layer_db(translator)]*3)
#db3 = concatenate_dbs([x_layer_db(translator)]*3)
#db4 = concatenate_dbs([z_layer_db(translator)]*3)

circuit_db = concatenate_dbs([circuit_db, db1])
c, circuit_db = translator.give_circuit(circuit_db)

cdb = []
for ind, qubits in list(translator.indexed_cnots.items()):
    cdb.append(gate_template(int(ind), block_id=0))
    con, tar = qubits
    cdb.append(gate_template(int(con + translator.number_of_cnots), param_value = np.random.random()))
    cdb.append(gate_template(int(tar + translator.number_of_cnots + translator.n_qubits), param_value = np.random.random()))
c6_db = pd.DataFrame(cdb)
circuit_db = concatenate_dbs([circuit_db, c6_db])

c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 1
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)

simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_1 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb34a696fd0>>

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 4.308824046522781e-16
#                                           ┌──┐                                                                                                                                                     ┌──┐                                                                                                                                           ┌──┐                                                                                                                                                       ┌──┐
# (0, 0): ───Rz(th_0)───@───@───@───X─────────X────────────X───Rx(th_4)───Rx(th_8)───Rx(th_12)───────────────@───────────Rz(th_16)───@───Rz(th_18)───@───Rz(th_20)───X───Rx(th_23)─────────────────────X────Rx(th_29)───────────────────────────────────X───Rx(th_35)───Rz(th_40)───────────────────────────@───────────────────────@───@───X─────────X────────────X───Rx(th_44)───Rx(th_48)───Rx(th_52)───────────────@───────────Rz(th_56)───@───Rz(th_58)───@───Rz(th_60)───X───Rx(th_63)─────────────────────X────Rx(th_69)───────────────────────────────────X───Rx(th_75)───────────────────────────────────
#                       │   │   │   │         │            │                                                 │                       │               │               │                                 │                                                │                                                   │                       │   │   │         │            │                                                   │                       │               │               │                                 │                                                │
# (0, 1): ───Rz(th_1)───X───┼───┼───@───@────@┼────X───────┼───X──────────Rx(th_5)───Rx(th_9)────Rx(th_13)───X───────────Rx(th_17)───┼───────────────┼───────────────@───Rz(th_22)───@───Rz(th_24)────@┼────Rz(th_26)───X───Rx(th_31)───────────────────┼───────────────X───────────Rx(th_37)───Rz(th_41)───X───────────────────────┼───┼───@───@────@┼────X───────┼───X───────────Rx(th_45)───Rx(th_49)───Rx(th_53)───X───────────Rx(th_57)───┼───────────────┼───────────────@───Rz(th_62)───@───Rz(th_64)────@┼────Rz(th_66)───X───Rx(th_71)───────────────────┼───────────────X───Rx(th_77)───────────────────
#                           │   │       │    ││    │       │   │                                                                     │               │                               │                ││                │                               │               │                                                           │   │       │    ││    │       │   │                                                                       │               │                               │                ││                │                               │               │
# (0, 2): ───Rz(th_2)───────X───┼───────X────┼@────@───@───┼───┼──────────X──────────Rx(th_6)────Rx(th_10)───Rx(th_14)───────────────X───Rx(th_19)───┼───────────────────────────────X───Rx(th_25)────┼@────Rz(th_28)───@───Rz(th_30)───@───Rz(th_32)───┼───────────────┼───────────────────────X───────────Rx(th_39)───Rz(th_42)───X───┼───────X────┼@────@───@───┼───┼───────────X───────────Rx(th_46)───Rx(th_50)───Rx(th_54)───────────────X───Rx(th_59)───┼───────────────────────────────X───Rx(th_65)────┼@────Rz(th_68)───@───Rz(th_70)───@───Rz(th_72)───┼───────────────┼───────────────X───Rx(th_79)───
#                               │            │         │   │   │          │                                                                          │                                                │                                 │               │               │                       │                                       │            │         │   │   │           │                                                                           │                                                │                                 │               │               │               │
# (0, 3): ───Rz(th_3)───────────X────────────X─────────X───@───@──────────@──────────Rx(th_7)────Rx(th_11)───Rx(th_15)───────────────────────────────X───Rx(th_21)────────────────────────────────────X─────Rx(th_27)───────────────────X───Rx(th_33)───@───Rz(th_34)───@───────────Rz(th_36)───@───────────Rz(th_38)───Rz(th_43)───────X────────────X─────────X───@───@───────────@───────────Rx(th_47)───Rx(th_51)───Rx(th_55)───────────────────────────────X───Rx(th_61)────────────────────────────────────X─────Rx(th_67)───────────────────X───Rx(th_73)───@───Rz(th_74)───@───Rz(th_76)───@───Rz(th_78)───
#                                           └──┘                                                                                                                                                     └──┘                                                                                                                                           └──┘                                                                                                                                                       └──┘
#
#                               ┌──┐                              ┌─────────┐   ┌─────────┐                                            ┌──────────┐                           ┌──────────┐                                                                                                                                                               ┌──┐                               ┌──────────┐   ┌──────────┐                                               ┌──────────┐                           ┌──────────┐
# (0, 0): ───Rz(th_3)───X─────────X────────────X───Rx(th_4)───@────────────@─────────────@────Rz(th_7)───Rz(th_8)───Rz(th_9)───X────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────X───Rx(th_23)───Rx(th_24)───Rx(th_25)───────────────@───────────@───────────@───Rz(th_35)───X─────────X────────────X───Rx(th_36)───@─────────────@──────────────@────Rz(th_39)───Rz(th_40)───Rz(th_41)───X────────────────────────────────────────────────────────X────────────────────────────────────────────────────────────X───Rx(th_55)───Rx(th_56)───Rx(th_57)───────────────────────────
#                       │         │            │              │            │             │                                     │                                                        │                                                            │                                                   │           │           │               │         │            │               │             │              │                                        │                                                        │                                                            │
# (0, 1): ───Rz(th_0)───@───@────@┼────X───────┼───X──────────X────Rx(th_5)┼─────Rx(th_6)┼─────────────────────────────────────@───@─────────────@────Rz(th_13)───Rz(th_14)────Rz(th_15)┼────X───────────────────────────────────────────────────────┼───X───────────Rx(th_26)───Rx(th_27)───Rz(th_32)───X───────────┼───────────┼───────────────@───@────@┼────X───────┼───X───────────X────Rx(th_37)┼─────Rx(th_38)┼────────────────────────────────────────@───@─────────────@────Rz(th_45)───Rz(th_46)────Rz(th_47)┼────X───────────────────────────────────────────────────────┼───X───────────Rx(th_58)───Rx(th_59)───────────────────────────
#                           │    ││    │       │   │                       │             │                                         │             │                                      │    │                                                       │   │                                                           │           │                   │    ││    │       │   │                         │              │                                            │             │                                      │    │                                                       │   │
# (0, 2): ───Rz(th_1)───────X────┼@────@───@───┼───┼──────────X────────────X─────────────┼─────────────────────────────────────────X────Rx(th_10)┼────Rx(th_11)───Rx(th_12)─────────────@────@───@───Rz(th_19)───Rz(th_20)───Rz(th_21)───────────────┼───┼───────────X───────────Rx(th_31)───Rz(th_33)───────────────X───────────┼───────────────────X────┼@────@───@───┼───┼───────────X─────────────X──────────────┼────────────────────────────────────────────X────Rx(th_42)┼────Rx(th_43)───Rx(th_44)─────────────@────@───@───Rz(th_51)───Rz(th_52)───Rz(th_53)───────────────┼───┼───────────X───────────Rx(th_63)───────────────────────────
#                                │         │   │   │          │                          │                                                       │                                               │                                                   │   │           │                                                           │                        │         │   │   │           │                            │                                                          │                                               │                                                   │   │           │
# (0, 3): ───Rz(th_2)────────────X─────────X───@───@──────────@──────────────────────────X───────────────────────────────────────────────────────X───────────────────────────────────────────────X───Rx(th_16)───Rx(th_17)───Rx(th_18)───Rx(th_22)───@───@───────────@───────────Rz(th_28)───Rz(th_29)───Rz(th_30)───Rz(th_34)───X────────────────────────X─────────X───@───@───────────@────────────────────────────X──────────────────────────────────────────────────────────X───────────────────────────────────────────────X───Rx(th_48)───Rx(th_49)───Rx(th_50)───Rx(th_54)───@───@───────────@───────────Rz(th_60)───Rz(th_61)───Rz(th_62)───
#                               └──┘                              └─────────┘   └─────────┘                                            └──────────┘                           └──────────┘                                                                                                                                                               └──┘                               └──────────┘   └──────────┘                                               └──────────┘                           └──────────┘

# %%
len(simplified_db), len(circuit_db)
# Out:
# (109, 128)

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [0])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)

q = 0
other_qs = list(range(translator.n_qubits))
other_qs.remove(q)
indds = [translator.cnots_index[str([q,k])] for k in other_qs]
cdb = pd.DataFrame([gate_template(i) for i in indds])

circuit_db = concatenate_dbs([z_layer_db(translator), cdb])

for q in range(1, translator.n_qubits):
    other_qs = list(range(translator.n_qubits))
    other_qs.remove(q)
    indds = [translator.cnots_index[str([q,k])] for k in other_qs]
    cdb = pd.DataFrame([gate_template(i) for i in indds])
    circuit_db = concatenate_dbs([circuit_db ,cdb])

c, circuit_db = translator.give_circuit(circuit_db)

db1 = concatenate_dbs([x_layer_db(translator)]*3)
#db2 = concatenate_dbs([z_layer_db(translator)]*3)
#db3 = concatenate_dbs([x_layer_db(translator)]*3)
#db4 = concatenate_dbs([z_layer_db(translator)]*3)

circuit_db = concatenate_dbs([circuit_db, db1])
c, circuit_db = translator.give_circuit(circuit_db)

cdb = []
for ind, qubits in list(translator.indexed_cnots.items()):
    cdb.append(gate_template(int(ind), block_id=0))
    con, tar = qubits
    cdb.append(gate_template(int(con + translator.number_of_cnots), param_value = np.random.random()))
    cdb.append(gate_template(int(tar + translator.number_of_cnots + translator.n_qubits), param_value = np.random.random()))
c6_db = pd.DataFrame(cdb)
circuit_db = concatenate_dbs([circuit_db, c6_db])

c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 2
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)

simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>
# simplified using  <bound method Simplifier.rule_6 of <utilities.simplifier.Simplifier object at 0x7fb27a92ed68>>

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [0])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)


ddb =concatenate_dbs([x_layer_db(translator)]*2 +[z_layer_db(translator)]*2 + [x_layer_db(translator)]*1 + [x_layer_db(translator)]*2 +  [z_layer_db(translator)]*2 )

cnots = list(np.squeeze(np.array([[k,k] for k in range(translator.number_of_cnots)]).reshape([-1,1])))
ddbc = pd.DataFrame([gate_template(k) for k in cnots])

cdb = concatenate_dbs([ddbc, ddb])
circuit, circuit_db = translator.give_circuit(cdb)


dd1  =circuit_db.copy()
dd1["block_id"] = 1
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)

simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7fb27a8cb7b8>>

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 0.00030185333546601135
#                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                    ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_36)───Rx(th_40)───Rz(th_44)───Rz(th_48)───Rx(th_52)───Rx(th_56)───Rx(th_60)───Rz(th_64)───Rz(th_68)───────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │                                                                                                                                    │           │           │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_37)───Rx(th_41)───Rz(th_45)───Rz(th_49)───Rx(th_53)───Rx(th_57)───Rx(th_61)───Rz(th_65)───Rz(th_69)───────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │                                                                                                                                             │   │   │   │           │   │    ││     ││    │   │           │   │   │           │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_38)───Rx(th_42)───Rz(th_46)───Rz(th_50)───Rx(th_54)───Rx(th_58)───Rx(th_62)───Rz(th_66)───Rz(th_70)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_39)───Rx(th_43)───Rz(th_47)───Rz(th_51)───Rx(th_55)───Rx(th_59)───Rx(th_63)───Rz(th_67)───Rz(th_71)───
#                                                    └──┘   └──┘                                                                                                                                                                                                                    └──┘   └──┘
#
#                                                    ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───Rz(th_36)───Rx(th_40)───Rz(th_44)───────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───Rz(th_37)───Rx(th_41)───Rz(th_45)───────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───Rz(th_38)───Rx(th_42)───Rz(th_46)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───Rz(th_39)───Rx(th_43)───Rz(th_47)───
#                                                    └──┘   └──┘

# %%
len(circuit_db), len(simplified_db)
# Out:
# (120, 72)

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [0,1])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)


ddb =concatenate_dbs([x_layer_db(translator)]*2 +[z_layer_db(translator)]*2 + [x_layer_db(translator)]*1 + [x_layer_db(translator)]*2 +  [z_layer_db(translator)]*2 )

cnots = list(np.squeeze(np.array([[k,k] for k in range(translator.number_of_cnots)]).reshape([-1,1])))
ddbc = pd.DataFrame([gate_template(k) for k in cnots])

cdb = concatenate_dbs([ddbc, ddb])
circuit, circuit_db = translator.give_circuit(cdb)


dd1  =circuit_db.copy()
dd1["block_id"] = 1
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 2
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)

simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d0697e2a9995> in <module>
#      34 simplifier.apply_relatives_to_first = True
#      35 simplifier.relative_rules = [simplifier.rule_1]
# ---> 36 simplified_db, ns = simplifier.reduce_circuit(circuit_db)
#      37 ss, simplified_db = translator.give_circuit(simplified_db)
#
# ~/Desktop/qvans/utilities/simplifier.py in reduce_circuit(self, circuit_db)
#      48                     blocked_circuit[block] = simplified_db[simplified_db["block_id"] == block]
#      49                     for rule in self.absolute_rules:
# ---> 50                         cnt, blocked_circuit[block]  = self.apply_rule(blocked_circuit[block]  , rule)
#      51                         final_cnt += cnt
#      52                     if (block == 0) and (self.apply_relatives_to_first == True):
#
# ~/Desktop/qvans/utilities/simplifier.py in apply_rule(self, original_circuit_db, rule, **kwargs)
#      75             if check_symbols_ordered(simplified_circuit_db) is False:
#      76                 simplified_db.to_csv("testing/data/dcl")
# ---> 77                 raise AttributeError("ojo {}".format(rule))
#      78             circuit, simplified_db = self.translator.give_circuit(simplified_circuit_db)
#      79             gates_on_qubit, on_qubit_order = self.get_positional_dbs(circuit, simplified_db)
#
# AttributeError: ojo <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7fb2bc039a20>>

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 1.1215123277163865
#                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                       ┌──┐   ┌──┐                                                                                                                                                                                                                             ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_36)───Rx(th_40)───Rz(th_44)───Rz(th_48)───Rx(th_52)───Rx(th_56)───Rx(th_60)───Rz(th_64)───Rz(th_68)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_72)───Rx(th_76)───Rz(th_80)───Rz(th_84)───Rx(th_88)───Rx(th_92)───Rx(th_96)───Rz(th_100)───Rz(th_104)─────────────────────────────@────────────@────────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_108)───Rx(th_112)───Rz(th_116)───Rz(th_120)───Rx(th_124)───Rx(th_128)───Rx(th_132)───Rz(th_136)───Rz(th_140)───────────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │                                                                                                                                    │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                       │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                           │            │            │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_37)───Rx(th_41)───Rz(th_45)───Rz(th_49)───Rx(th_53)───Rx(th_57)───Rx(th_61)───Rz(th_65)───Rz(th_69)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_73)───Rx(th_77)───Rz(th_81)───Rz(th_85)───Rx(th_89)───Rx(th_93)────Rx(th_97)────Rz(th_101)───Rz(th_105)───X────────────X────────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X────────────X────────────Rx(th_109)───Rx(th_113)───Rz(th_117)───Rz(th_121)───Rx(th_125)───Rx(th_129)───Rx(th_133)───Rz(th_137)───Rz(th_141)─────────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │                                                                                                                                             │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                               │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                                     │   │   │   │           │   │    ││     ││    │   │           │   │   │            │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_38)───Rx(th_42)───Rz(th_46)───Rz(th_50)───Rx(th_54)───Rx(th_58)───Rx(th_62)───Rz(th_66)───Rz(th_70)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_74)───Rx(th_78)───Rz(th_82)───Rz(th_86)────Rx(th_90)────Rx(th_94)────Rx(th_98)────Rz(th_102)───Rz(th_106)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼────────────┼────────────X────────────X────────────Rx(th_110)───Rx(th_114)───Rz(th_118)───Rz(th_122)───Rx(th_126)───Rx(th_130)───Rx(th_134)───Rz(th_138)───Rz(th_142)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                                     │   │                    │      │             │   │   │   │   │            │            │            │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_39)───Rx(th_43)───Rz(th_47)───Rz(th_51)───Rx(th_55)───Rx(th_59)───Rx(th_63)───Rz(th_67)───Rz(th_71)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_75)───Rx(th_79)───Rz(th_83)───Rz(th_87)────Rx(th_91)────Rx(th_95)────Rx(th_99)────Rz(th_103)───Rz(th_107)───────────X───X────────────────────X──────X─────────────X───X───@───@───@────────────@────────────@────────────@────────────Rx(th_111)───Rx(th_115)───Rz(th_119)───Rz(th_123)───Rx(th_127)───Rx(th_131)───Rx(th_135)───Rz(th_139)───Rz(th_143)───
#                                                    └──┘   └──┘                                                                                                                                                                                                                    └──┘   └──┘                                                                                                                                                                                                                       └──┘   └──┘                                                                                                                                                                                                                             └──┘   └──┘
#
#                                                    ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───Rz(th_36)───Rx(th_40)───Rz(th_44)───────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───Rz(th_37)───Rx(th_41)───Rz(th_45)───────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───Rz(th_38)───Rx(th_42)───Rz(th_46)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───Rz(th_39)───Rx(th_43)───Rz(th_47)───
#                                                    └──┘   └──┘

# %%
import pandas as pd
cc = pd.read_csv("testing/data/dcl")

# %%
ppp = cc.drop("Unnamed: 0", axis=1)

# %%
ss,ddb = translator.give_circuit(ppp)
# Out:
# warning, repeated symbol while constructing the circuit, see circuut_
#   symbol_name th_72
#  symbols ['th_72', 'th_73', 'th_74', 'th_75', 'th_76', 'th_77', 'th_78', 'th_79', 'th_80', 'th_81', 'th_82', 'th_83', 'th_84', 'th_85', 'th_86', 'th_87', 'th_88', 'th_89', 'th_90', 'th_91', 'th_92', 'th_93', 'th_94', 'th_95', 'th_96', 'th_97', 'th_98', 'th_99', 'th_100', 'th_101', 'th_102', 'th_103']
# circuit_db {0: {'ind': 16, 'symbol': 'th_72', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 1: {'ind': 17, 'symbol': 'th_73', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 2: {'ind': 18, 'symbol': 'th_74', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 3: {'ind': 19, 'symbol': 'th_75', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 4: {'ind': 12, 'symbol': 'th_76', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 5: {'ind': 13, 'symbol': 'th_77', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 6: {'ind': 14, 'symbol': 'th_78', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 7: {'ind': 15, 'symbol': 'th_79', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 8: {'ind': 16, 'symbol': 'th_80', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 9: {'ind': 17, 'symbol': 'th_81', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 10: {'ind': 18, 'symbol': 'th_82', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 11: {'ind': 19, 'symbol': 'th_83', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 12: {'ind': 12, 'symbol': 'th_84', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 13: {'ind': 13, 'symbol': 'th_85', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 14: {'ind': 14, 'symbol': 'th_86', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 15: {'ind': 15, 'symbol': 'th_87', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 16: {'ind': 16, 'symbol': 'th_88', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 17: {'ind': 17, 'symbol': 'th_89', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 18: {'ind': 18, 'symbol': 'th_90', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 19: {'ind': 19, 'symbol': 'th_91', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 20: {'ind': 12, 'symbol': 'th_92', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 21: {'ind': 13, 'symbol': 'th_93', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 22: {'ind': 14, 'symbol': 'th_94', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 23: {'ind': 15, 'symbol': 'th_95', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 24: {'ind': 16, 'symbol': 'th_96', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 25: {'ind': 17, 'symbol': 'th_97', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 26: {'ind': 18, 'symbol': 'th_98', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 27: {'ind': 19, 'symbol': 'th_99', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 28: {'ind': 12, 'symbol': 'th_100', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 29: {'ind': 13, 'symbol': 'th_101', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 30: {'ind': 14, 'symbol': 'th_102', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 31: {'ind': 15, 'symbol': 'th_103', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 32: {'ind': 12, 'symbol': 'th_72', 'param_value': -16.343067169189453, 'trainable': True, 'block_id': 2}}
#
#
#
# warning, repeated symbol while constructing the circuit, see circuut_
#   symbol_name th_76
#  symbols ['th_72', 'th_73', 'th_74', 'th_75', 'th_76', 'th_77', 'th_78', 'th_79', 'th_80', 'th_81', 'th_82', 'th_83', 'th_84', 'th_85', 'th_86', 'th_87', 'th_88', 'th_89', 'th_90', 'th_91', 'th_92', 'th_93', 'th_94', 'th_95', 'th_96', 'th_97', 'th_98', 'th_99', 'th_100', 'th_101', 'th_102', 'th_103', 'th_72']
# circuit_db {0: {'ind': 16, 'symbol': 'th_72', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 1: {'ind': 17, 'symbol': 'th_73', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 2: {'ind': 18, 'symbol': 'th_74', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 3: {'ind': 19, 'symbol': 'th_75', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 4: {'ind': 12, 'symbol': 'th_76', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 5: {'ind': 13, 'symbol': 'th_77', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 6: {'ind': 14, 'symbol': 'th_78', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 7: {'ind': 15, 'symbol': 'th_79', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 8: {'ind': 16, 'symbol': 'th_80', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 9: {'ind': 17, 'symbol': 'th_81', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 10: {'ind': 18, 'symbol': 'th_82', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 11: {'ind': 19, 'symbol': 'th_83', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 12: {'ind': 12, 'symbol': 'th_84', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 13: {'ind': 13, 'symbol': 'th_85', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 14: {'ind': 14, 'symbol': 'th_86', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 15: {'ind': 15, 'symbol': 'th_87', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 16: {'ind': 16, 'symbol': 'th_88', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 17: {'ind': 17, 'symbol': 'th_89', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 18: {'ind': 18, 'symbol': 'th_90', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 19: {'ind': 19, 'symbol': 'th_91', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 20: {'ind': 12, 'symbol': 'th_92', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 21: {'ind': 13, 'symbol': 'th_93', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 22: {'ind': 14, 'symbol': 'th_94', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 23: {'ind': 15, 'symbol': 'th_95', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 24: {'ind': 16, 'symbol': 'th_96', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 25: {'ind': 17, 'symbol': 'th_97', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 26: {'ind': 18, 'symbol': 'th_98', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 27: {'ind': 19, 'symbol': 'th_99', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 28: {'ind': 12, 'symbol': 'th_100', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 29: {'ind': 13, 'symbol': 'th_101', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 30: {'ind': 14, 'symbol': 'th_102', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 31: {'ind': 15, 'symbol': 'th_103', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 32: {'ind': 12, 'symbol': 'th_72', 'param_value': -16.343067169189453, 'trainable': True, 'block_id': 2}, 33: {'ind': 16, 'symbol': 'th_76', 'param_value': -6.2833309173583975, 'trainable': True, 'block_id': 2}}
#
#
#
# warning, repeated symbol while constructing the circuit, see circuut_
#   symbol_name th_80
#  symbols ['th_72', 'th_73', 'th_74', 'th_75', 'th_76', 'th_77', 'th_78', 'th_79', 'th_80', 'th_81', 'th_82', 'th_83', 'th_84', 'th_85', 'th_86', 'th_87', 'th_88', 'th_89', 'th_90', 'th_91', 'th_92', 'th_93', 'th_94', 'th_95', 'th_96', 'th_97', 'th_98', 'th_99', 'th_100', 'th_101', 'th_102', 'th_103', 'th_72', 'th_76']
# circuit_db {0: {'ind': 16, 'symbol': 'th_72', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 1: {'ind': 17, 'symbol': 'th_73', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 2: {'ind': 18, 'symbol': 'th_74', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 3: {'ind': 19, 'symbol': 'th_75', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 4: {'ind': 12, 'symbol': 'th_76', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 5: {'ind': 13, 'symbol': 'th_77', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 6: {'ind': 14, 'symbol': 'th_78', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 7: {'ind': 15, 'symbol': 'th_79', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 8: {'ind': 16, 'symbol': 'th_80', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 9: {'ind': 17, 'symbol': 'th_81', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 10: {'ind': 18, 'symbol': 'th_82', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 11: {'ind': 19, 'symbol': 'th_83', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 12: {'ind': 12, 'symbol': 'th_84', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 13: {'ind': 13, 'symbol': 'th_85', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 14: {'ind': 14, 'symbol': 'th_86', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 15: {'ind': 15, 'symbol': 'th_87', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 16: {'ind': 16, 'symbol': 'th_88', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 17: {'ind': 17, 'symbol': 'th_89', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 18: {'ind': 18, 'symbol': 'th_90', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 19: {'ind': 19, 'symbol': 'th_91', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 20: {'ind': 12, 'symbol': 'th_92', 'param_value': 3.448296944257913, 'trainable': True, 'block_id': 2}, 21: {'ind': 13, 'symbol': 'th_93', 'param_value': 4.493667318642263, 'trainable': True, 'block_id': 2}, 22: {'ind': 14, 'symbol': 'th_94', 'param_value': 3.7872739882393165, 'trainable': True, 'block_id': 2}, 23: {'ind': 15, 'symbol': 'th_95', 'param_value': 3.4236020095353483, 'trainable': True, 'block_id': 2}, 24: {'ind': 16, 'symbol': 'th_96', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 25: {'ind': 17, 'symbol': 'th_97', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 26: {'ind': 18, 'symbol': 'th_98', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 27: {'ind': 19, 'symbol': 'th_99', 'param_value': 0.0, 'trainable': True, 'block_id': 2}, 28: {'ind': 12, 'symbol': 'th_100', 'param_value': 2.661901610522322, 'trainable': True, 'block_id': 2}, 29: {'ind': 13, 'symbol': 'th_101', 'param_value': 4.058272401214204, 'trainable': True, 'block_id': 2}, 30: {'ind': 14, 'symbol': 'th_102', 'param_value': 2.749441536415439, 'trainable': True, 'block_id': 2}, 31: {'ind': 15, 'symbol': 'th_103', 'param_value': 5.603175015853413, 'trainable': True, 'block_id': 2}, 32: {'ind': 12, 'symbol': 'th_72', 'param_value': -16.343067169189453, 'trainable': True, 'block_id': 2}, 33: {'ind': 16, 'symbol': 'th_76', 'param_value': -6.2833309173583975, 'trainable': True, 'block_id': 2}, 34: {'ind': 12, 'symbol': 'th_80', 'param_value': -15.41881275177002, 'trainable': True, 'block_id': 2}}

# %%
ss
# Out:
# (0, 0): ───Rx(th_72)───Rz(th_76)───Rx(th_80)───Rz(th_84)───Rx(th_88)───Rz(th_92)───Rx(th_96)───Rz(th_100)───Rz(th_72)───Rx(th_76)───Rz(th_80)───
#
# (0, 1): ───Rx(th_73)───Rz(th_77)───Rx(th_81)───Rz(th_85)───Rx(th_89)───Rz(th_93)───Rx(th_97)───Rz(th_101)───────────────────────────────────────
#
# (0, 2): ───Rx(th_74)───Rz(th_78)───Rx(th_82)───Rz(th_86)───Rx(th_90)───Rz(th_94)───Rx(th_98)───Rz(th_102)───────────────────────────────────────
#
# (0, 3): ───Rx(th_75)───Rz(th_79)───Rx(th_83)───Rz(th_87)───Rx(th_91)───Rz(th_95)───Rx(th_99)───Rz(th_103)───────────────────────────────────────

# %% [markdown]
# ss

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)


ddb =concatenate_dbs([x_layer_db(translator)]*2 +[z_layer_db(translator)]*2 + [x_layer_db(translator)]*1 + [x_layer_db(translator)]*2 +  [z_layer_db(translator)]*2 )

cnots = list(np.squeeze(np.array([[k,k] for k in range(translator.number_of_cnots)]).reshape([-1,1])))
ddbc = pd.DataFrame([gate_template(k) for k in cnots])

cdb = concatenate_dbs([ddbc, ddb])
circuit, circuit_db = translator.give_circuit(cdb)

simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>
# simplified using  <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7f5aa3a80080>>

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 0.0003018533354660049
#                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                       ┌──┐   ┌──┐                                                                                                                                                                                                                             ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_36)───Rx(th_40)───Rz(th_44)───Rz(th_48)───Rx(th_52)───Rx(th_56)───Rx(th_60)───Rz(th_64)───Rz(th_68)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_72)───Rx(th_76)───Rz(th_80)───Rz(th_84)───Rx(th_88)───Rx(th_92)───Rx(th_96)───Rz(th_100)───Rz(th_104)─────────────────────────────@────────────@────────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_108)───Rx(th_112)───Rz(th_116)───Rz(th_120)───Rx(th_124)───Rx(th_128)───Rx(th_132)───Rz(th_136)───Rz(th_140)───────────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │                                                                                                                                    │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                       │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                           │            │            │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_37)───Rx(th_41)───Rz(th_45)───Rz(th_49)───Rx(th_53)───Rx(th_57)───Rx(th_61)───Rz(th_65)───Rz(th_69)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_73)───Rx(th_77)───Rz(th_81)───Rz(th_85)───Rx(th_89)───Rx(th_93)────Rx(th_97)────Rz(th_101)───Rz(th_105)───X────────────X────────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X────────────X────────────Rx(th_109)───Rx(th_113)───Rz(th_117)───Rz(th_121)───Rx(th_125)───Rx(th_129)───Rx(th_133)───Rz(th_137)───Rz(th_141)─────────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │                                                                                                                                             │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                               │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                                     │   │   │   │           │   │    ││     ││    │   │           │   │   │            │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_38)───Rx(th_42)───Rz(th_46)───Rz(th_50)───Rx(th_54)───Rx(th_58)───Rx(th_62)───Rz(th_66)───Rz(th_70)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_74)───Rx(th_78)───Rz(th_82)───Rz(th_86)────Rx(th_90)────Rx(th_94)────Rx(th_98)────Rz(th_102)───Rz(th_106)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼────────────┼────────────X────────────X────────────Rx(th_110)───Rx(th_114)───Rz(th_118)───Rz(th_122)───Rx(th_126)───Rx(th_130)───Rx(th_134)───Rz(th_138)───Rz(th_142)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                                     │   │                    │      │             │   │   │   │   │            │            │            │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_39)───Rx(th_43)───Rz(th_47)───Rz(th_51)───Rx(th_55)───Rx(th_59)───Rx(th_63)───Rz(th_67)───Rz(th_71)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_75)───Rx(th_79)───Rz(th_83)───Rz(th_87)────Rx(th_91)────Rx(th_95)────Rx(th_99)────Rz(th_103)───Rz(th_107)───────────X───X────────────────────X──────X─────────────X───X───@───@───@────────────@────────────@────────────@────────────Rx(th_111)───Rx(th_115)───Rz(th_119)───Rz(th_123)───Rx(th_127)───Rx(th_131)───Rx(th_135)───Rz(th_139)───Rz(th_143)───
#                                                    └──┘   └──┘                                                                                                                                                                                                                    └──┘   └──┘                                                                                                                                                                                                                       └──┘   └──┘                                                                                                                                                                                                                             └──┘   └──┘
#
# (0, 0): ───Rz(th_0)───Rx(th_4)───Rz(th_8)────
#
# (0, 1): ───Rz(th_1)───Rx(th_5)───Rz(th_9)────
#
# (0, 2): ───Rz(th_2)───Rx(th_6)───Rz(th_10)───
#
# (0, 3): ───Rz(th_3)───Rx(th_7)───Rz(th_11)───

# %%
np.random.seed(0)
translator = CirqTranslater(4, untouchable_blocks = [0,1])

translator.env_qubits = [2]

simplifier = Simplifier(translator)
etas = [0.01, 1.]
minimizer = Minimizer(translator, mode="discrimination", params=etas)

ddb =concatenate_dbs([x_layer_db(translator)]*2 +[z_layer_db(translator)]*2 + [x_layer_db(translator)]*1 + [x_layer_db(translator)]*2 +  [z_layer_db(translator)]*2 )

cnots = list(np.squeeze(np.array([[k,k] for k in range(translator.number_of_cnots)]).reshape([-1,1])))
ddbc = pd.DataFrame([gate_template(k) for k in cnots])

cdb = concatenate_dbs([ddbc, ddb])
circuit, circuit_db = translator.give_circuit(cdb)

dd1  =circuit_db.copy()
dd1["block_id"] = 1
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)


dd1  =circuit_db.copy()
dd1["block_id"] = 2
dd1["symbol"] = None
circuit_db = concatenate_dbs([circuit_db, dd1])
c, circuit_db = translator.give_circuit(circuit_db)



simplifier = Simplifier(translator, apply_relatives_to_first = True)
simplifier.apply_relatives_to_first = True
simplifier.relative_rules = [simplifier.rule_1]
simplified_db, ns = simplifier.reduce_circuit(circuit_db)
ss, simplified_db = translator.give_circuit(simplified_db)
# Out:
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_2 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# simplified using  <bound method Simplifier.rule_4 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-600ebe7b90bd> in <module>
#      34 simplifier.apply_relatives_to_first = True
#      35 simplifier.relative_rules = [simplifier.rule_1]
# ---> 36 simplified_db, ns = simplifier.reduce_circuit(circuit_db)
#      37 ss, simplified_db = translator.give_circuit(simplified_db)
#
# ~/Desktop/qvans/utilities/simplifier.py in reduce_circuit(self, circuit_db)
#      48                     blocked_circuit[block] = simplified_db[simplified_db["block_id"] == block]
#      49                     for rule in self.absolute_rules:
# ---> 50                         cnt, blocked_circuit[block]  = self.apply_rule(blocked_circuit[block]  , rule)
#      51                         final_cnt += cnt
#      52                     if (block == 0) and (self.apply_relatives_to_first == True):
#
# ~/Desktop/qvans/utilities/simplifier.py in apply_rule(self, original_circuit_db, rule, **kwargs)
#      75             if check_symbols_ordered(simplified_circuit_db) is False:
#      76                 simplified_db.to_csv("testing/data/dcl")
# ---> 77                 raise AttributeError("ojo {}".format(rule))
#      78             circuit, simplified_db = self.translator.give_circuit(simplified_circuit_db)
#      79             gates_on_qubit, on_qubit_order = self.get_positional_dbs(circuit, simplified_db)
#
# AttributeError: ojo <bound method Simplifier.rule_5 of <utilities.simplifier.Simplifier object at 0x7f5ab3633470>>

# %%
mdif = max_diff(translator , circuit_db, simplified_db)
print("\n")
print(mdif)
print(c)
print()
print(ss)
# Out:
# 0.000301853335466016
#                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                       ┌──┐   ┌──┐                                                                                                                                                                                                                             ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_36)───Rx(th_40)───Rz(th_44)───Rz(th_48)───Rx(th_52)───Rx(th_56)───Rx(th_60)───Rz(th_64)───Rz(th_68)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_72)───Rx(th_76)───Rz(th_80)───Rz(th_84)───Rx(th_88)───Rx(th_92)───Rx(th_96)───Rz(th_100)───Rz(th_104)─────────────────────────────@────────────@────────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_108)───Rx(th_112)───Rz(th_116)───Rz(th_120)───Rx(th_124)───Rx(th_128)───Rx(th_132)───Rz(th_136)───Rz(th_140)───────────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │                                                                                                                                    │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                       │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                           │            │            │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_37)───Rx(th_41)───Rz(th_45)───Rz(th_49)───Rx(th_53)───Rx(th_57)───Rx(th_61)───Rz(th_65)───Rz(th_69)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_73)───Rx(th_77)───Rz(th_81)───Rz(th_85)───Rx(th_89)───Rx(th_93)────Rx(th_97)────Rz(th_101)───Rz(th_105)───X────────────X────────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X────────────X────────────Rx(th_109)───Rx(th_113)───Rz(th_117)───Rz(th_121)───Rx(th_125)───Rx(th_129)───Rx(th_133)───Rz(th_137)───Rz(th_141)─────────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │                                                                                                                                             │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                               │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                                     │   │   │   │           │   │    ││     ││    │   │           │   │   │            │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_38)───Rx(th_42)───Rz(th_46)───Rz(th_50)───Rx(th_54)───Rx(th_58)───Rx(th_62)───Rz(th_66)───Rz(th_70)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_74)───Rx(th_78)───Rz(th_82)───Rz(th_86)────Rx(th_90)────Rx(th_94)────Rx(th_98)────Rz(th_102)───Rz(th_106)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼────────────┼────────────X────────────X────────────Rx(th_110)───Rx(th_114)───Rz(th_118)───Rz(th_122)───Rx(th_126)───Rx(th_130)───Rx(th_134)───Rz(th_138)───Rz(th_142)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                                     │   │                    │      │             │   │   │   │   │            │            │            │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_39)───Rx(th_43)───Rz(th_47)───Rz(th_51)───Rx(th_55)───Rx(th_59)───Rx(th_63)───Rz(th_67)───Rz(th_71)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_75)───Rx(th_79)───Rz(th_83)───Rz(th_87)────Rx(th_91)────Rx(th_95)────Rx(th_99)────Rz(th_103)───Rz(th_107)───────────X───X────────────────────X──────X─────────────X───X───@───@───@────────────@────────────@────────────@────────────Rx(th_111)───Rx(th_115)───Rz(th_119)───Rz(th_123)───Rx(th_127)───Rx(th_131)───Rx(th_135)───Rz(th_139)───Rz(th_143)───
#                                                    └──┘   └──┘                                                                                                                                                                                                                    └──┘   └──┘                                                                                                                                                                                                                       └──┘   └──┘                                                                                                                                                                                                                             └──┘   └──┘
#
#                                                    ┌──┐   ┌──┐                                                                                                                                                                                                                                                        ┌──┐   ┌──┐                                                                                                                                                                                                                       ┌──┐   ┌──┐
# (0, 0): ───@───@───@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_0)───Rx(th_4)───Rz(th_8)───Rz(th_12)───Rx(th_16)───Rx(th_20)───Rx(th_24)───Rz(th_28)───Rz(th_32)───Rz(th_36)───Rx(th_40)───Rz(th_44)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_48)───Rx(th_52)───Rz(th_56)───Rz(th_60)───Rx(th_64)───Rx(th_68)───Rx(th_72)───Rz(th_76)───Rz(th_80)───────────────────────────@───────────@───────────@───@───@───@───X───X─────────────X──────X────────────────────X───X───Rx(th_84)───Rx(th_88)───Rz(th_92)───Rz(th_96)───Rx(th_100)───Rx(th_104)───Rx(th_108)───Rz(th_112)───Rz(th_116)───────────────────────────────────────────────────────
#            │   │   │   │   │   │   │   │             │      │                    │   │                                                                                                                                                                        │           │           │   │   │   │   │   │             │      │                    │   │                                                                                                                                       │           │           │   │   │   │   │   │             │      │                    │   │
# (0, 1): ───X───X───┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X──────────X──────────Rx(th_1)───Rx(th_5)────Rz(th_9)────Rz(th_13)───Rx(th_17)───Rx(th_21)───Rx(th_25)───Rz(th_29)───Rz(th_33)───Rz(th_37)───Rx(th_41)───Rz(th_45)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_49)───Rx(th_53)───Rz(th_57)───Rz(th_61)───Rx(th_65)───Rx(th_69)───Rx(th_73)───Rz(th_77)───Rz(th_81)───X───────────X───────────┼───┼───┼───┼───@───@───@───@────@┼─────@┼────X───X───────────┼───┼───X───────────X───────────Rx(th_85)───Rx(th_89)───Rz(th_93)────Rz(th_97)────Rx(th_101)───Rx(th_105)───Rx(th_109)───Rz(th_113)───Rz(th_117)─────────────────────────────
#                    │   │   │   │           │   │    ││     ││    │   │           │   │   │          │                                                                                                                                                                                 │   │   │   │           │   │    ││     ││    │   │           │   │   │           │                                                                                                                                               │   │   │   │           │   │    ││     ││    │   │           │   │   │           │
# (0, 2): ───────────X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼──────────┼──────────X──────────X───────────Rx(th_2)────Rx(th_6)────Rz(th_10)───Rz(th_14)───Rx(th_18)───Rx(th_22)───Rx(th_26)───Rz(th_30)───Rz(th_34)───Rz(th_38)───Rx(th_42)───Rz(th_46)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_50)───Rx(th_54)───Rz(th_58)───Rz(th_62)───Rx(th_66)───Rx(th_70)───Rx(th_74)───Rz(th_78)───Rz(th_82)───X───X───┼───┼───────────X───X────┼@─────┼@────@───@───@───@───┼───┼───┼───────────┼───────────X───────────X───────────Rx(th_86)────Rx(th_90)────Rz(th_94)────Rz(th_98)────Rx(th_102)───Rx(th_106)───Rx(th_110)───Rz(th_114)───Rz(th_118)───
#                            │   │                    │      │             │   │   │   │   │          │          │          │                                                                                                                                                                   │   │                    │      │             │   │   │   │   │           │           │           │                                                                                                                               │   │                    │      │             │   │   │   │   │           │           │           │
# (0, 3): ───────────────────X───X────────────────────X──────X─────────────X───X───@───@───@──────────@──────────@──────────@───────────Rx(th_3)────Rx(th_7)────Rz(th_11)───Rz(th_15)───Rx(th_19)───Rx(th_23)───Rx(th_27)───Rz(th_31)───Rz(th_35)───Rz(th_39)───Rx(th_43)───Rz(th_47)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_51)───Rx(th_55)───Rz(th_59)───Rz(th_63)───Rx(th_67)───Rx(th_71)───Rx(th_75)───Rz(th_79)───Rz(th_83)───────────X───X────────────────────X──────X─────────────X───X───@───@───@───────────@───────────@───────────@───────────Rx(th_87)────Rx(th_91)────Rz(th_95)────Rz(th_99)────Rx(th_103)───Rx(th_107)───Rx(th_111)───Rz(th_115)───Rz(th_119)───
#                                                    └──┘   └──┘                                                                                                                                                                                                                                                        └──┘   └──┘                                                                                                                                                                                                                       └──┘   └──┘

# %%
check_symbols_ordered(simplified_db)
# Out:
# True
